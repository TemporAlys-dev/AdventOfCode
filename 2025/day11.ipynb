# %%
from AOC_utils import get_day
import numpy as np

input_data = get_day(day=11, year=2025)

# print out first few lines to get a feel for the data
print(len(input_data))
input_data[:7]
# Out:
# Day 11 input already downloaded
# 609
# ['smx: otc',
#  'mmh: gvp',
#  'gbo: hyf alz',
#  'laa: vky qjq',
#  'vrn: tbs tsr jix',
#  'xyl: xel eur wdj',
#  'sxm: out']

# %%
example = '''
aaa: you hhh
you: bbb ccc
bbb: ddd eee
ccc: ddd eee fff
ddd: ggg
eee: out
fff: out
ggg: out
hhh: ccc fff iii
iii: out
'''.split('\n')[1:-1]

# %%
example2 = '''
svr: aaa bbb
aaa: fft
fft: ccc
bbb: tty
tty: ccc
ccc: ddd eee
ddd: hub
hub: fff
eee: dac
dac: fff
fff: ggg hhh
ggg: out
hhh: out
'''.split('\n')[1:-1]

# %%
from functools import cache

def solve_day(data):
    part1 = 0; part2 = 0

    data = {line.split(': ')[0]: line.split(': ')[1].split(' ') for line in data}
    
    def dfs(node):
        if data[node][0] == 'out':
            return 1
        counts = [dfs(child) for child in data[node]]
        part2_count = sum(counts)
        return part2_count
    
    part1 = dfs('you')
    
    @cache
    def dfs2(node, found_fft=False, found_dac=False):
        if data[node][0] == 'out':
            return 1, found_fft, found_dac
        if node == 'fft':
            found_fft = True
        if node == 'dac':
            found_dac = True
        counts = [dfs2(child, found_fft, found_dac) for child in data[node]]
        part2_count = sum(c[0] for c in counts if c[1] and c[2])
        found_fft = any(c[1] for c in counts)
        found_dac = any(c[2] for c in counts)
        return part2_count, found_fft, found_dac
    
    part2 = dfs2('svr')[0]
    
    print("part 1:", part1)
    print("part 2:", part2)

# solve_day(example)
# solve_day(example2)

# %%
solve_day(input_data)
# Out:
# part 1: 796
# part 2: 294053029111296
